# %%
# import necessary packages
import os
import matplotlib.pyplot as plt
import geopandas as gpd
from descartes import PolygonPatch
import pandas as pd
import numpy as np
import seaborn as sns
import fiona
import cbsodata
import pyproj

# %%
movements = pd.read_csv("data/movementage.csv",decimal=",").drop(index=101)

# %%
movements.plot()

# %%
percentage_movements = movements["2018* (x 1 000)"] / sum(movements["2018* (x 1 000)"])

# %%
pd.DataFrame(percentage_movements).rename(columns={"2018* (x 1 000)":"percent"}).to_csv("output/movementage.csv")
